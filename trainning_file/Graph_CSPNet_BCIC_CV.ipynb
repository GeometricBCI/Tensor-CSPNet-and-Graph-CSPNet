# %%
# !pip install mne pyriemann geoopt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mne
#   Downloading mne-1.1.1-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 3.8 MB/s
# Collecting pyriemann
#   Downloading pyriemann-0.3.tar.gz (365 kB)
#      |████████████████████████████████| 365 kB 17.2 MB/s
# Collecting geoopt
#   Downloading geoopt-0.5.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 9.7 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne) (21.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne) (4.64.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from mne) (1.21.6)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from mne) (3.2.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne) (2.11.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from mne) (1.7.3)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.24.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.3.5)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from geoopt) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.9.0->geoopt) (4.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->mne) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyriemann) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyriemann) (3.1.0)
# Building wheels for collected packages: pyriemann
#   Building wheel for pyriemann (setup.py) ... done
#   Created wheel for pyriemann: filename=pyriemann-0.3-py2.py3-none-any.whl size=78033 sha256=ee4147d228a9eb66271fd65dafbe050605eaa03a945eb0fb3a799b5d132e4f9a
#   Stored in directory: /root/.cache/pip/wheels/0b/1b/bf/a537f9e17e6c3490004ede419c72f863af1d0d765d25e532ef
# Successfully built pyriemann
# Installing collected packages: pyriemann, mne, geoopt
# Successfully installed geoopt-0.5.0 mne-1.1.1 pyriemann-0.3

# %%
import time
import pandas as pd
import numpy as np



#import torch and sklearn
from torch.autograd import Variable
import torch.nn.functional as F
import torch as th
from torch.utils.data.sampler import SubsetRandomSampler
import torch.utils.data
from sklearn.model_selection import StratifiedShuffleSplit


#import util folder
from Geometric_Methods.utils.model import Graph_CSPNet_Basic
from Geometric_Methods.utils.early_stopping import EarlyStopping
from Geometric_Methods.utils.load_data import load_KU, load_BCIC, dataloader_in_main
from Geometric_Methods.utils.args import args_parser
import Geometric_Methods.utils.geoopt as geoopt

# %%
import argparse

def args_parser():
    parser = argparse.ArgumentParser()

    parser.add_argument('--alg_name', default = 'Graph_CSPNet', help = 'name of model')
    parser.add_argument('--mlp',      default = False, help = 'whether the classifier is a multiple layer perception or not')

    parser.add_argument('--no-cuda',  action = 'store_true', default=False, help='disables CUDA training')
    parser.add_argument('--initial_lr', type = float, default = 1e-3, help="initial_lr for optimizer")
    parser.add_argument('--decay',      type = float, default = 1, help="decay rate for adjust_learning")

    parser.add_argument('--start_No', type=int, default = 8,  help='testing starts on subject #')
    parser.add_argument('--end_No',   type=int, default = 9,  help='testing ends on subject #')
    parser.add_argument('--epochs',   type=int, default = 50, help='number of epochs to train')
    parser.add_argument('--patience', type=int, default = 10, help='patience for early stopping')

    parser.add_argument('--train_batch_size', type = int, default = 29, help = 'batch size in each epoch for trainning')
    parser.add_argument('--test_batch_size',  type = int, default = 29, help = 'batch size in each epoch for testing')
    parser.add_argument('--valid_batch_size', type = int, default = 29, help = 'batch size in each epoch for validation')

    parser.add_argument('--seed',         type = int, default = 1, metavar='S', help='random seed (default: 1)')
    parser.add_argument('--log_interval', type = int, default = 1, help='how many batches to wait before logging training status')
    parser.add_argument('--save-model', action = 'store_true', default=False, help='for Saving the current Model')

    parser.add_argument('--folder_name',         default = 'results')
    parser.add_argument('--weights_folder_path', default = 'model_paras/')

    args = parser.parse_args(args=[])

    return args

# %%
def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    optimizer.lr = args.initial_lr * (args.decay ** (epoch // 100))

def main(args, train, test, train_y, test_y, graph_matrix, adjacency_matrix, sub, total_sub, kf_iter, validation):

    use_cuda = not args.no_cuda and torch.cuda.is_available()
    device   = torch.device("cuda" if use_cuda else "cpu")

    if validation:
        index_split = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=42)
        for train_index, valid_index in index_split.split(train,train_y):
            train_sampler = SubsetRandomSampler(train_index)
            valid_sampler = SubsetRandomSampler(valid_index)
            
        train       = Variable(torch.from_numpy(train)).double()
        test        = Variable(torch.from_numpy(test)).double()
        train_y     = Variable(torch.LongTensor(train_y))
        test_y      = Variable(torch.LongTensor(test_y))
          
        train_dataset = dataloader_in_main(train, train_y)
        test_dataset  = dataloader_in_main(test, test_y)

        train_kwargs = {'batch_size': args.train_batch_size}
        if use_cuda:
              cuda_kwargs ={'num_workers': 100,
                            'sampler': train_sampler,
                              'pin_memory': True,
                              'shuffle': True     
              }
              train_kwargs.update(cuda_kwargs)
              
        valid_kwargs = {'batch_size': args.valid_batch_size}
        if use_cuda:
              cuda_kwargs ={'num_workers': 100,
                            'sampler':valid_sampler,
                              'pin_memory': True,
                              'shuffle': True     
              }
              valid_kwargs.update(cuda_kwargs)

        test_kwargs = {'batch_size': args.test_batch_size}
        if use_cuda:
              cuda_kwargs ={'num_workers': 100,
                              'pin_memory': True,
                              'shuffle': True      
              }
              test_kwargs.update(cuda_kwargs)

        train_loader  = torch.utils.data.DataLoader(dataset= train_dataset, **train_kwargs)
        valid_loader  = torch.utils.data.DataLoader(dataset= train_dataset, **valid_kwargs)
        test_loader   = torch.utils.data.DataLoader(dataset= test_dataset,  **test_kwargs)
    else:
        train       = Variable(torch.from_numpy(train)).double()
        test        = Variable(torch.from_numpy(test)).double()
        train_y     = Variable(torch.LongTensor(train_y))
        test_y      = Variable(torch.LongTensor(test_y))

        train_dataset = dataloader_in_main(train, train_y)
        test_dataset  = dataloader_in_main(test, test_y)

        train_kwargs  = {'batch_size': args.train_batch_size}

        if use_cuda:
            cuda_kwargs = {'num_workers': 100,
                            'pin_memory': True,
                            'shuffle': True		
        }
            train_kwargs.update(cuda_kwargs)

        test_kwargs = {'batch_size': args.test_batch_size}
        if use_cuda:
            cuda_kwargs  = {'num_workers': 100,
                            'pin_memory': True,
                            'shuffle': True      
            }
            test_kwargs.update(cuda_kwargs)

        train_loader  = torch.utils.data.DataLoader(dataset= train_dataset, **train_kwargs)
        test_loader   = torch.utils.data.DataLoader(dataset= test_dataset,  **test_kwargs)

    

    model = Graph_CSPNet_Basic(channel_num = train.shape[1],
        P = Variable(torch.from_numpy(graph_matrix)).double(),  
        mlp = args.mlp,
        dataset = 'BCIC',
        ).to(device)

    optimizer = geoopt.optim.RiemannianAdam(model.parameters(), lr=args.initial_lr)

    early_stopping = EarlyStopping(
        alg_name = args.alg_name, 
        path_w   = args.weights_folder_path + args.alg_name + '_checkpoint.pt', 
        patience = args.patience, 
        verbose  = True, 
        )

    print('#####Start Trainning######')

    for epoch in range(1, args.epochs+1):

        adjust_learning_rate(optimizer, epoch)

        model.train()

        train_correct = 0
    
        for batch_idx, (batch_train, batch_train_y) in enumerate(train_loader):

            optimizer.zero_grad()

            logits = model(batch_train.to(device))
            output = F.log_softmax(logits, dim = -1)
            loss   = F.nll_loss(output, batch_train_y.to(device))


            loss.backward()
            optimizer.step()

            if batch_idx % args.log_interval == 0:
                print('----#------#-----#-----#-----#-----#-----#-----')
                pred    = output.data.max(1, keepdim=True)[1]
                train_correct += pred.eq(batch_train_y.to(device).data.view_as(pred)).long().cpu().sum()
                torch.save(model.state_dict(), args.weights_folder_path + args.alg_name+'_model.pth')
                torch.save(optimizer.state_dict(), args.weights_folder_path+'optimizer.pth')


                print('['+args.alg_name+': Sub No.{}/{} Fold {}/10, Epoch {}/{}, Completed {:.0f}%]:\nTrainning loss {:.10f} Acc.: {:.4f}'.format(\
                        sub, total_sub, kf_iter+1, epoch, args.epochs, 100. * (1+batch_idx) / len(train_loader), loss.cpu().detach().numpy(),\
                        train_correct.item()/len(train_loader.dataset)))
                    

        if validation:
            #Validate the Model
            valid_losses  = []
            valid_loss    =  0
            valid_correct =  0

            model.eval()

            for batch_idx, (batch_valid, batch_valid_y) in enumerate(valid_loader):

                logits         = model(batch_valid.to(device))
                output         = F.log_softmax(logits, dim = -1)
                valid_loss    += F.nll_loss(output, batch_valid_y.to(device))
                valid_losses.append(valid_loss.item())
                
                
                pred           = output.data.max(1, keepdim=True)[1]
                valid_correct += pred.eq(batch_valid_y.to(device).data.view_as(pred)).long().cpu().sum()

            print('Validate loss: {:.10f} Acc: {:.4f}'.format(sum(valid_losses), valid_correct.item()/len(valid_loader.dataset)))
            
            early_stopping(np.average(valid_losses), model)
            
            if early_stopping.early_stop:
              print("Early Stopping!")
              break
        else:
            pass
        

    #Testing
    print('###############################################################')
    print('START TESTING')
    print('###############################################################')

    
    model.eval()

    test_loss    = 0
    test_correct = 0

    with torch.no_grad():
        for batch_idx, (batch_test, batch_test_y) in enumerate(test_loader):

            logits        = model(batch_test.to(device))
            output        = F.log_softmax(logits, dim = -1)
            test_loss    += F.nll_loss(output, batch_test_y.to(device))
            
            test_pred     = output.data.max(1, keepdim=True)[1]
            test_correct += test_pred.eq(batch_test_y.to(device).data.view_as(test_pred)).long().cpu().sum()

            print('-----------------------------------')
            print('Testing Batch {}:'.format(batch_idx))
            print('  Pred Label:', test_pred.view(1, test_pred.shape[0]).cpu().numpy()[0])
            print('Ground Truth:', batch_test_y.numpy())


    return test_correct.item()/len(test_loader.dataset), test_loss.item()/len(test_loader.dataset)


if __name__ == '__main__':

    args   = args_parser()

    alg_df = pd.DataFrame(columns=['R1', 'R2', 'R3','R4', 'R5', 'R6', 'R7', 'R8','R9', 'R10','Avg'])

    print('############Start Task#################')
    
    for sub in range(args.start_No, args.end_No + 1):

        BCIC_dataset = load_BCIC(
            sub, 
            TorE     = True, 
            alg_name = args.alg_name,
            scenario = 'CV'
            )

        alg_record = []

        start      = time.time()

        for kf_iter in range(0, 10):

            x_train_stack, x_test_stack, y_train, y_test = BCIC_dataset.generate_training_test_set_CV(kf_iter)

            graph_M, adj_M = BCIC_dataset.LGT_graph_matrix_fn()

            print('###Graph Generated!###')

            acc, loss = main(
                args       = args, 
                train      = x_train_stack, 
                test       = x_test_stack, 
                train_y    = y_train, 
                test_y     = y_test,
                graph_matrix     = graph_M,
                adjacency_matrix = adj_M,
                sub        = sub, 
                total_sub  = args.end_No - args.start_No + 1,
                kf_iter    = kf_iter, 
                validation = False,
                )
            
            print('##############################################################')

            print(args.alg_name + ' Testing Loss.: {:4f} Acc: {:4f}'.format(loss, acc))

            alg_record.append(acc)

        end = time.time()

        alg_record.append(np.mean(alg_record))
        
        alg_df.loc[sub] = alg_record
 
        alg_df.to_csv(args.folder_name + '/' \
        + time.strftime("[%Y-%m-%d %H:%M:%S]", time.localtime()) \
        + args.alg_name \
        +'_Sub(' \
        + str(args.start_No) \
        +'-' \
        +str(args.end_No) \
        +')' \
        +'_' \
        + str(args.epochs)\
        + '.csv'\
        , index = False)
# Out:
# Streaming output truncated to the last 5000 lines.
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 17/50, Completed 44%]:
# Trainning loss 0.3755193087 Acc.: 0.4054
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 17/50, Completed 56%]:
# Trainning loss 0.4089548070 Acc.: 0.4942
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 17/50, Completed 67%]:
# Trainning loss 0.4846548814 Acc.: 0.5869
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 17/50, Completed 78%]:
# Trainning loss 0.3358911564 Acc.: 0.6795
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 17/50, Completed 89%]:
# Trainning loss 0.2805603229 Acc.: 0.7722
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 17/50, Completed 100%]:
# Trainning loss 0.4596896533 Acc.: 0.8533
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 11%]:
# Trainning loss 0.3353859801 Acc.: 0.1042
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 22%]:
# Trainning loss 0.3991007178 Acc.: 0.1931
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 33%]:
# Trainning loss 0.4304886999 Acc.: 0.2780
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 44%]:
# Trainning loss 0.2938679377 Acc.: 0.3784
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 56%]:
# Trainning loss 0.2081146280 Acc.: 0.4788
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 67%]:
# Trainning loss 0.3882328564 Acc.: 0.5753
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 78%]:
# Trainning loss 0.3965798583 Acc.: 0.6641
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 89%]:
# Trainning loss 0.3917463891 Acc.: 0.7568
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 18/50, Completed 100%]:
# Trainning loss 0.5218746554 Acc.: 0.8378
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 11%]:
# Trainning loss 0.2101564782 Acc.: 0.1042
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 22%]:
# Trainning loss 0.1535364200 Acc.: 0.2162
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 33%]:
# Trainning loss 0.4013308535 Acc.: 0.3089
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 44%]:
# Trainning loss 0.5711015238 Acc.: 0.3822
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 56%]:
# Trainning loss 0.1953711950 Acc.: 0.4903
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 67%]:
# Trainning loss 0.2182796624 Acc.: 0.6023
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 78%]:
# Trainning loss 0.1989509520 Acc.: 0.7104
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 89%]:
# Trainning loss 0.3521786584 Acc.: 0.8069
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 19/50, Completed 100%]:
# Trainning loss 0.6982822403 Acc.: 0.8803
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 20/50, Completed 11%]:
# Trainning loss 0.2813364216 Acc.: 0.0965
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 20/50, Completed 22%]:
# Trainning loss 0.1494420098 Acc.: 0.2046
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 20/50, Completed 33%]:
# Trainning loss 0.2224361762 Acc.: 0.3127
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 20/50, Completed 44%]:
# Trainning loss 0.5205309913 Acc.: 0.3938
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 20/50, Completed 56%]:
# Trainning loss 0.3304629309 Acc.: 0.4865
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch
Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 22%]:
# Trainning loss 0.0274632283 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 33%]:
# Trainning loss 0.0350793419 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 44%]:
# Trainning loss 0.0286985343 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 56%]:
# Trainning loss 0.0276090283 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 67%]:
# Trainning loss 0.0362000036 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 78%]:
# Trainning loss 0.0320630084 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 89%]:
# Trainning loss 0.0304436322 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 47/50, Completed 100%]:
# Trainning loss 0.0394915419 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 11%]:
# Trainning loss 0.0243944333 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 22%]:
# Trainning loss 0.0265775260 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 33%]:
# Trainning loss 0.0338996173 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 44%]:
# Trainning loss 0.0277759034 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 56%]:
# Trainning loss 0.0266379776 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 67%]:
# Trainning loss 0.0350747207 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 78%]:
# Trainning loss 0.0310138078 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 89%]:
# Trainning loss 0.0294149059 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 48/50, Completed 100%]:
# Trainning loss 0.0381861763 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 11%]:
# Trainning loss 0.0236036659 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 22%]:
# Trainning loss 0.0257304354 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 33%]:
# Trainning loss 0.0327783500 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 44%]:
# Trainning loss 0.0269070344 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 56%]:
# Trainning loss 0.0257891395 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 67%]:
# Trainning loss 0.0339577571 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 78%]:
# Trainning loss 0.0299564905 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 89%]:
# Trainning loss 0.0284506088 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 49/50, Completed 100%]:
# Trainning loss 0.0368668047 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 11%]:
# Trainning loss 0.0228798126 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 22%]:
# Trainning loss 0.0249302205 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 33%]:
# Trainning loss 0.0317094468 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 44%]:
# Trainning loss 0.0260696092 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 56%]:
# Trainning loss 0.0249300291 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 67%]:
# Trainning loss 0.0329217792 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 78%]:
# Trainning loss 0.0290019509 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 89%]:
# Trainning loss 0.0275219177 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 7/10, Epoch 50/50, Completed 100%]:
# Trainning loss 0.0356797326 Acc.: 1.0000
# ###############################################################
# START TESTING
# ###############################################################
# -----------------------------------
# Testing Batch 0:
#   Pred Label: [1 0 1 3 2 2 0 3 3 2 3 0 2 2 2 3 1 3 0 3 2 1 0 1 0 3 1 0 0]
# Ground Truth: [2 0 1 3 2 2 0 3 3 2 3 0 2 1 2 3 1 3 0 2 2 1 0 1 0 3 1 1 0]
# ##############################################################
# Graph_CSPNet Testing Loss.: 0.017369 Acc: 0.862069
# ###Graph Generated!###
# #####Start Trainning######
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 8/10, Epoch 1/50, Completed 11%]:
# Trainning loss 1.4044282067 Acc.: 0.0232
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 8/10, Epoch 1/50, Completed 22%]:
# Trainning loss 5.8618598603 Acc.: 0.0579
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 8/10, Epoch 1/50, Completed 33%]:
# Trainning loss 1.7615471155 Acc.: 0.0888
# ...
# Trainning loss 0.0366521254 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 40/50, Completed 11%]:
# Trainning loss 0.0169322056 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 40/50, Completed 22%]:
# Trainning loss 0.0169924658 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 40/50, Completed 33%]:
# Trainning loss 0.0222775726 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch
Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 22%]:
# Trainning loss 0.0116935533 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 33%]:
# Trainning loss 0.0186058893 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 44%]:
# Trainning loss 0.0131746127 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 56%]:
# Trainning loss 0.0160948024 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 67%]:
# Trainning loss 0.0203172924 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 78%]:
# Trainning loss 0.0170805771 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 89%]:
# Trainning loss 0.0141750770 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 46/50, Completed 100%]:
# Trainning loss 0.0230738086 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 11%]:
# Trainning loss 0.0115039516 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 22%]:
# Trainning loss 0.0115374396 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 33%]:
# Trainning loss 0.0181154763 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 44%]:
# Trainning loss 0.0127536505 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 56%]:
# Trainning loss 0.0155824153 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 67%]:
# Trainning loss 0.0198398923 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 78%]:
# Trainning loss 0.0166521434 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 89%]:
# Trainning loss 0.0138228806 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 47/50, Completed 100%]:
# Trainning loss 0.0223786215 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 11%]:
# Trainning loss 0.0112490913 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 22%]:
# Trainning loss 0.0112758190 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 33%]:
# Trainning loss 0.0178069781 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 44%]:
# Trainning loss 0.0125001474 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 56%]:
# Trainning loss 0.0153000704 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 67%]:
# Trainning loss 0.0193937416 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 78%]:
# Trainning loss 0.0162111246 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 89%]:
# Trainning loss 0.0135528582 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 48/50, Completed 100%]:
# Trainning loss 0.0216864768 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 11%]:
# Trainning loss 0.0110343285 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 22%]:
# Trainning loss 0.0110728711 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 33%]:
# Trainning loss 0.0174108887 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 44%]:
# Trainning loss 0.0121937021 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 56%]:
# Trainning loss 0.0149427824 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 67%]:
# Trainning loss 0.0189274705 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 78%]:
# Trainning loss 0.0158266300 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 89%]:
# Trainning loss 0.0132060460 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 49/50, Completed 100%]:
# Trainning loss 0.0211751124 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 11%]:
# Trainning loss 0.0108458790 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 22%]:
# Trainning loss 0.0108828336 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 33%]:
# Trainning loss 0.0170409430 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 44%]:
# Trainning loss 0.0119340041 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 56%]:
# Trainning loss 0.0146553575 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 67%]:
# Trainning loss 0.0184929560 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 78%]:
# Trainning loss 0.0154436142 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 89%]:
# Trainning loss 0.0129479652 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Graph_CSPNet: Sub No.9/2 Fold 10/10, Epoch 50/50, Completed 100%]:
# Trainning loss 0.0205665304 Acc.: 1.0000
# ###############################################################
# START TESTING
# ###############################################################
# -----------------------------------
# Testing Batch 0:
#   Pred Label: [0 2 0 0 1 0 0 3 1 3 3 2 2 1 3 3 1 3 3 3 0 0 2 0 3 2 0 0]
# Ground Truth: [1 2 0 0 1 0 1 3 1 3 3 2 2 1 3 2 1 3 3 1 0 0 2 2 3 2 0 0]
# ##############################################################
# Graph_CSPNet Testing Loss.: 0.019306 Acc: 0.821429
