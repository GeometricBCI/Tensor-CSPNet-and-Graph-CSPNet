# %%
# !pip install mne pyriemann geoopt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mne
#   Downloading mne-1.1.1-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 4.3 MB/s
# Collecting pyriemann
#   Downloading pyriemann-0.3.tar.gz (365 kB)
#      |████████████████████████████████| 365 kB 51.5 MB/s
# Collecting geoopt
#   Downloading geoopt-0.5.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 7.9 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from mne) (1.21.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from mne) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne) (2.11.3)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne) (4.64.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from mne) (1.7.3)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.0.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyriemann) (1.3.5)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from geoopt) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.9.0->geoopt) (4.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->mne) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyriemann) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyriemann) (3.1.0)
# Building wheels for collected packages: pyriemann
#   Building wheel for pyriemann (setup.py) ... done
#   Created wheel for pyriemann: filename=pyriemann-0.3-py2.py3-none-any.whl size=78033 sha256=6558be42809a5738280a05611c36abcf5da877bc758a5e19f61adfca83e66245
#   Stored in directory: /root/.cache/pip/wheels/0b/1b/bf/a537f9e17e6c3490004ede419c72f863af1d0d765d25e532ef
# Successfully built pyriemann
# Installing collected packages: pyriemann, mne, geoopt
# Successfully installed geoopt-0.5.0 mne-1.1.1 pyriemann-0.3

# %%
import time
import pandas as pd
import numpy as np



#import torch and sklearn
from torch.autograd import Variable
import torch.nn.functional as F
import torch as th
from torch.utils.data.sampler import SubsetRandomSampler
import torch.utils.data
from sklearn.model_selection import StratifiedShuffleSplit


#import util folder
from Geometric_Methods.utils.model import Tensor_CSPNet_Basic
from Geometric_Methods.utils.early_stopping import EarlyStopping
from Geometric_Methods.utils.load_data import load_KU, load_BCIC, dataloader_in_main
from Geometric_Methods.utils.args import args_parser
import Geometric_Methods.utils.geoopt as geoopt

# %%
import argparse

def args_parser():
    parser = argparse.ArgumentParser()

    parser.add_argument('--alg_name', default = 'Tensor_CSPNet', help = 'name of model')
    parser.add_argument('--mlp',      default = False, help = 'whether the classifier is a multiple layer perception or not')

    parser.add_argument('--no-cuda',  action = 'store_true', default=False, help='disables CUDA training')
    parser.add_argument('--initial_lr', type = float, default = 1e-3, help="initial_lr for optimizer.")
    parser.add_argument('--decay',      type = float, default = 1, help="decay rate for adjust_learning")

    parser.add_argument('--start_No', type=int, default = 1,  help='testing starts on subject #')
    parser.add_argument('--end_No',   type=int, default = 9,  help='testing ends on subject #')
    parser.add_argument('--epochs',   type=int, default = 50, help='number of epochs to train')
    parser.add_argument('--patience', type=int, default = 10, help='patience for early stopping')

    parser.add_argument('--train_batch_size', type = int, default = 29, help = 'batch size in each epoch for trainning')
    parser.add_argument('--test_batch_size',  type = int, default = 29, help = 'batch size in each epoch for testing')
    parser.add_argument('--valid_batch_size', type = int, default = 29, help = 'batch size in each epoch for validation')

    parser.add_argument('--seed',         type = int, default = 1, metavar='S', help='random seed (default: 1)')
    parser.add_argument('--log_interval', type = int, default = 1, help='how many batches to wait before logging training status')
    parser.add_argument('--save-model', action = 'store_true', default=False, help='for Saving the current Model')

    parser.add_argument('--folder_name',         default = 'results')
    parser.add_argument('--weights_folder_path', default = 'model_paras/')

    args = parser.parse_args(args=[])

    return args

# %%
def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    optimizer.lr = args.initial_lr * (args.decay ** (epoch // 100))


def main(args, train, test, train_y, test_y, sub, total_sub, kf_iter, validation):

    use_cuda = not args.no_cuda and torch.cuda.is_available()
    device   = torch.device("cuda" if use_cuda else "cpu")

    if validation:
        index_split = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=42)
        for train_index, valid_index in index_split.split(train,train_y):
            train_sampler = SubsetRandomSampler(train_index)
            valid_sampler = SubsetRandomSampler(valid_index)
            
        train       = Variable(torch.from_numpy(train)).double()
        test        = Variable(torch.from_numpy(test)).double()
        train_y     = Variable(torch.LongTensor(train_y))
        test_y      = Variable(torch.LongTensor(test_y))
          
        train_dataset = dataloader_in_main(train, train_y)
        test_dataset  = dataloader_in_main(test, test_y)

        train_kwargs = {'batch_size': args.train_batch_size}
        if use_cuda:
              cuda_kwargs ={'num_workers': 100,
                            'sampler': train_sampler,
                              'pin_memory': True,
                              'shuffle': True     
              }
              train_kwargs.update(cuda_kwargs)
              
        valid_kwargs = {'batch_size': args.valid_batch_size}
        if use_cuda:
              cuda_kwargs ={'num_workers': 10,
                            'sampler':valid_sampler,
                              'pin_memory': True,
                              'shuffle': True     
              }
              valid_kwargs.update(cuda_kwargs)

        test_kwargs = {'batch_size': args.test_batch_size}
        if use_cuda:
              cuda_kwargs ={'num_workers': 1,
                              'pin_memory': True,
                              'shuffle': True      
              }
              test_kwargs.update(cuda_kwargs)

        train_loader  = torch.utils.data.DataLoader(dataset= train_dataset, **train_kwargs)
        valid_loader  = torch.utils.data.DataLoader(dataset= train_dataset, **valid_kwargs)
        test_loader   = torch.utils.data.DataLoader(dataset= test_dataset,  **test_kwargs)
    else:
        train       = Variable(torch.from_numpy(train)).double()
        test        = Variable(torch.from_numpy(test)).double()
        train_y     = Variable(torch.LongTensor(train_y))
        test_y      = Variable(torch.LongTensor(test_y))

        train_dataset = dataloader_in_main(train, train_y)
        test_dataset  = dataloader_in_main(test, test_y)

        train_kwargs  = {'batch_size': args.train_batch_size}

        if use_cuda:
            cuda_kwargs = {'num_workers': 100,
                            'pin_memory': True,
                            'shuffle': True,		
        }
            train_kwargs.update(cuda_kwargs)

        test_kwargs = {'batch_size': args.test_batch_size}
        if use_cuda:
            cuda_kwargs  = {'num_workers': 100,
                            'pin_memory': True,
                            'shuffle': True,      
            }
            test_kwargs.update(cuda_kwargs)

        train_loader  = torch.utils.data.DataLoader(dataset= train_dataset, **train_kwargs)
        test_loader   = torch.utils.data.DataLoader(dataset= test_dataset,  **test_kwargs)


    model = Tensor_CSPNet_Basic(channel_num = train.shape[1]*train.shape[2], 
        mlp = args.mlp,
        dataset = 'BCIC',
        ).to(device)

    optimizer = geoopt.optim.RiemannianAdam(model.parameters(), lr=args.initial_lr)
    """MixOptimizer is for StiefelParameter, SPDParameter, etc."""
    #optimizer = MixOptimizer(model.parameters(), lr= args.initial_lr)

    early_stopping = EarlyStopping(
        alg_name = args.alg_name, 
        path_w   = args.weights_folder_path + args.alg_name + '_checkpoint.pt', 
        patience = args.patience, 
        verbose  = True, 
        )

    print('#####Start Trainning######')

    for epoch in range(1, args.epochs+1):

        adjust_learning_rate(optimizer, epoch)

        model.train()

        train_correct = 0
    
        for batch_idx, (batch_train, batch_train_y) in enumerate(train_loader):

            optimizer.zero_grad()

            logits = model(batch_train.to(device))
            output = F.log_softmax(logits, dim = -1)
            loss   = F.nll_loss(output, batch_train_y.to(device))

            loss.backward()
            optimizer.step()

            if batch_idx % args.log_interval == 0:
                print('----#------#-----#-----#-----#-----#-----#-----')
                pred    = output.data.max(1, keepdim=True)[1]
                train_correct += pred.eq(batch_train_y.to(device).data.view_as(pred)).long().cpu().sum()
                torch.save(model.state_dict(), args.weights_folder_path + args.alg_name+'_model.pth')
                torch.save(optimizer.state_dict(), args.weights_folder_path+'optimizer.pth')


                print('['+args.alg_name+': Sub No.{}/{} Fold {}/10, Epoch {}/{}, Completed {:.0f}%]:\nTrainning loss {:.10f} Acc.: {:.4f}'.format(\
                        sub, total_sub, kf_iter+1, epoch, args.epochs, 100. * (1+batch_idx) / len(train_loader), loss.cpu().detach().numpy(),\
                        train_correct.item()/len(train_loader.dataset)))
                    
        if validation:
            #Validate the Model
            valid_losses  = []
            valid_loss    =  0
            valid_correct =  0

            model.eval()

            for batch_idx, (batch_valid, batch_valid_y) in enumerate(valid_loader):

                logits         = model(batch_valid.to(device))
                output         = F.log_softmax(logits, dim = -1)
                valid_loss    += F.nll_loss(output, batch_valid_y.to(device))
                valid_losses.append(valid_loss.item())
                
                
                pred           = output.data.max(1, keepdim=True)[1]
                valid_correct += pred.eq(batch_valid_y.to(device).data.view_as(pred)).long().cpu().sum()

            print('Validate loss: {:.10f} Acc: {:.4f}'.format(sum(valid_losses), valid_correct.item()/len(valid_loader.dataset)))
            
            early_stopping(np.average(valid_losses), model)
            
            if early_stopping.early_stop:
              print("Early Stopping!")
              break
        else:
            pass
        

    #Testing
    print('###############################################################')
    print('START TESTING')
    print('###############################################################')

    
    model.eval()

    test_loss    = 0
    test_correct = 0

    with torch.no_grad():
        for batch_idx, (batch_test, batch_test_y) in enumerate(test_loader):

            logits        = model(batch_test.to(device))
            output        = F.log_softmax(logits, dim = -1)
            test_loss    += F.nll_loss(output, batch_test_y.to(device))
            
            test_pred     = output.data.max(1, keepdim=True)[1]
            test_correct += test_pred.eq(batch_test_y.to(device).data.view_as(test_pred)).long().cpu().sum()

            print('-----------------------------------')
            print('Testing Batch {}:'.format(batch_idx))
            print('  Pred Label:', test_pred.view(1, test_pred.shape[0]).cpu().numpy()[0])
            print('Ground Truth:', batch_test_y.numpy())


    return test_correct.item()/len(test_loader.dataset), test_loss.item()/len(test_loader.dataset)

# %%
if __name__ == '__main__':

    args   = args_parser()

    alg_df = pd.DataFrame(columns=['R1', 'R2', 'R3','R4', 'R5', 'R6', 'R7', 'R8','R9', 'R10','Avg'])

    print('############Start Task#################')
    
    for sub in range(args.start_No, args.end_No + 1):

        BCIC_dataset = load_BCIC(sub,
            TorE     = True, 
            alg_name = args.alg_name,
            scenario = 'CV'
            )

        alg_record = []

        start      = time.time()

        for kf_iter in range(0, 10):

            x_train_stack, x_test_stack, y_train, y_test = BCIC_dataset.generate_training_test_set_CV(kf_iter)

            acc, loss = main(
                args       = args, 
                train      = x_train_stack, 
                test       = x_test_stack, 
                train_y    = y_train, 
                test_y     = y_test,
                kf_iter    = kf_iter, 
                sub        = sub, 
                total_sub  = args.end_No - args.start_No + 1, 
                validation = False,
                )
            
            print('##################################################################')

            print(args.alg_name + ' Testing Loss.: {:4f} Acc: {:4f}'.format(loss, acc))

            alg_record.append(acc)

        end = time.time()

        alg_record.append(np.mean(alg_record))
        
        alg_df.loc[sub] = alg_record
 
        alg_df.to_csv(args.folder_name + '/' \
        + time.strftime("[%Y-%m-%d %H:%M:%S]", time.localtime()) \
        + args.alg_name \
        +'_Sub(' \
        + str(args.start_No) \
        +'-' \
        +str(args.end_No) \
        +')' \
        +'_' \
        + str(args.epochs)\
        + '.csv'\
        , index = False)
# Out:
# ############Start Task#################
# #####Start Trainning######
# /content/drive/MyDrive/BCIC_第二篇/Geometric_Methods/utils/geoopt/linalg/batch_linalg.py:118: UserWarning: An output with one or more elements was resized since it had shape [1, 22, 22], which does not match the required output shape [1, 1, 22, 22]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  ../aten/src/ATen/native/Resize.cpp:17.)
#   return expm(x)
# Streaming output truncated to the last 5000 lines.
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 33%]:
# Trainning loss 0.2366576055 Acc.: 0.3282
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 44%]:
# Trainning loss 0.0958075175 Acc.: 0.4363
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 56%]:
# Trainning loss 0.0740202722 Acc.: 0.5483
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 67%]:
# Trainning loss 0.1237825530 Acc.: 0.6602
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 78%]:
# Trainning loss 0.1884280073 Acc.: 0.7606
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 89%]:
# Trainning loss 0.2660569246 Acc.: 0.8649
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 17/50, Completed 100%]:
# Trainning loss 0.1390744635 Acc.: 0.9653
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 11%]:
# Trainning loss 0.0671145541 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 22%]:
# Trainning loss 0.1786414634 Acc.: 0.2162
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 33%]:
# Trainning loss 0.3663143958 Acc.: 0.3127
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 44%]:
# Trainning loss 0.1618842787 Acc.: 0.4170
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 56%]:
# Trainning loss 0.1116062742 Acc.: 0.5290
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 67%]:
# Trainning loss 0.1018948796 Acc.: 0.6409
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 78%]:
# Trainning loss 0.2087144598 Acc.: 0.7375
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 89%]:
# Trainning loss 0.5091687232 Acc.: 0.8263
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 18/50, Completed 100%]:
# Trainning loss 0.2906843377 Acc.: 0.9189
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 11%]:
# Trainning loss 0.1139271483 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 22%]:
# Trainning loss 0.1171784032 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 33%]:
# Trainning loss 0.4727730948 Acc.: 0.3127
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 44%]:
# Trainning loss 0.4491421194 Acc.: 0.4015
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 56%]:
# Trainning loss 0.4473469044 Acc.: 0.4865
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 67%]:
# Trainning loss 0.0669268834 Acc.: 0.5985
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 78%]:
# Trainning loss 0.2053917192 Acc.: 0.6950
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 89%]:
# Trainning loss 0.9525921458 Acc.: 0.7645
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 19/50, Completed 100%]:
# Trainning loss 0.8558763516 Acc.: 0.8456
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 20/50, Completed 11%]:
# Trainning loss 0.6746057710 Acc.: 0.0888
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 20/50, Completed 22%]:
# Trainning loss 0.2969217629 Acc.: 0.1815
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch
Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 46/50, Completed 44%]:
# Trainning loss 0.0076014059 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 46/50, Completed 56%]:
# Trainning loss 0.0068541431 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 46/50, Completed 67%]:
# Trainning loss 0.0078929331 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 46/50, Completed 78%]:
# Trainning loss 0.0060338934 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 46/50, Completed 89%]:
# Trainning loss 0.0071435141 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 46/50, Completed 100%]:
# Trainning loss 0.0094258900 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 11%]:
# Trainning loss 0.0056658256 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 22%]:
# Trainning loss 0.0062216636 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 33%]:
# Trainning loss 0.0075098554 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 44%]:
# Trainning loss 0.0073196698 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 56%]:
# Trainning loss 0.0066153711 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 67%]:
# Trainning loss 0.0076409810 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 78%]:
# Trainning loss 0.0058374261 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 89%]:
# Trainning loss 0.0069059825 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 47/50, Completed 100%]:
# Trainning loss 0.0090886084 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 11%]:
# Trainning loss 0.0054857816 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 22%]:
# Trainning loss 0.0060220247 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 33%]:
# Trainning loss 0.0072489821 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 44%]:
# Trainning loss 0.0070453064 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 56%]:
# Trainning loss 0.0063908984 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 67%]:
# Trainning loss 0.0074019444 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 78%]:
# Trainning loss 0.0056530479 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 89%]:
# Trainning loss 0.0066784203 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 48/50, Completed 100%]:
# Trainning loss 0.0087719157 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 11%]:
# Trainning loss 0.0053134765 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 22%]:
# Trainning loss 0.0058325555 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 33%]:
# Trainning loss 0.0069982984 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 44%]:
# Trainning loss 0.0067895412 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 56%]:
# Trainning loss 0.0061779147 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 67%]:
# Trainning loss 0.0071744123 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 78%]:
# Trainning loss 0.0054754949 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 89%]:
# Trainning loss 0.0064629555 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 49/50, Completed 100%]:
# Trainning loss 0.0084690080 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 11%]:
# Trainning loss 0.0051487093 Acc.: 0.1120
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 22%]:
# Trainning loss 0.0056518254 Acc.: 0.2239
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 33%]:
# Trainning loss 0.0067618701 Acc.: 0.3359
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 44%]:
# Trainning loss 0.0065492894 Acc.: 0.4479
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 56%]:
# Trainning loss 0.0059739457 Acc.: 0.5598
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 67%]:
# Trainning loss 0.0069567791 Acc.: 0.6718
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 78%]:
# Trainning loss 0.0053063987 Acc.: 0.7838
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 7/10, Epoch 50/50, Completed 89%]:
# Trainning loss 0.0062587223 Acc.: 0.8958
# ----#------#-----#-----#-----#-----#-----#-----
# ...
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 11%]:
# Trainning loss 0.0155054244 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 22%]:
# Trainning loss 0.0154473576 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 33%]:
# Trainning loss 0.0194059745 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 44%]:
# Trainning loss 0.0150504113 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 56%]:
# Trainning loss 0.0171328500 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 67%]:
# Trainning loss 0.0182662756 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 40/50, Completed 78%]:
# Trainning loss 0.0182769954 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch
Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 46/50, Completed 67%]:
# Trainning loss 0.0133088904 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 46/50, Completed 78%]:
# Trainning loss 0.0132941366 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 46/50, Completed 89%]:
# Trainning loss 0.0146269671 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 46/50, Completed 100%]:
# Trainning loss 0.0177846220 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 11%]:
# Trainning loss 0.0108774176 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 22%]:
# Trainning loss 0.0107578718 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 33%]:
# Trainning loss 0.0135857462 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 44%]:
# Trainning loss 0.0105761675 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 56%]:
# Trainning loss 0.0118888425 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 67%]:
# Trainning loss 0.0126823055 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 78%]:
# Trainning loss 0.0126656078 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 89%]:
# Trainning loss 0.0139317936 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 47/50, Completed 100%]:
# Trainning loss 0.0169379820 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 11%]:
# Trainning loss 0.0103901608 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 22%]:
# Trainning loss 0.0102660644 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 33%]:
# Trainning loss 0.0129721363 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 44%]:
# Trainning loss 0.0101038257 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 56%]:
# Trainning loss 0.0113402718 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 67%]:
# Trainning loss 0.0120990719 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 78%]:
# Trainning loss 0.0120806989 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 89%]:
# Trainning loss 0.0132854501 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 48/50, Completed 100%]:
# Trainning loss 0.0161503624 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 11%]:
# Trainning loss 0.0099350946 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 22%]:
# Trainning loss 0.0098070853 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 33%]:
# Trainning loss 0.0123990231 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 44%]:
# Trainning loss 0.0096624854 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 56%]:
# Trainning loss 0.0108287240 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 67%]:
# Trainning loss 0.0115552493 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 78%]:
# Trainning loss 0.0115355294 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 89%]:
# Trainning loss 0.0126829499 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 49/50, Completed 100%]:
# Trainning loss 0.0154166668 Acc.: 1.0000
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 11%]:
# Trainning loss 0.0095093696 Acc.: 0.1115
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 22%]:
# Trainning loss 0.0093781826 Acc.: 0.2231
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 33%]:
# Trainning loss 0.0118628733 Acc.: 0.3346
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 44%]:
# Trainning loss 0.0092494602 Acc.: 0.4462
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 56%]:
# Trainning loss 0.0103508903 Acc.: 0.5577
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 67%]:
# Trainning loss 0.0110473024 Acc.: 0.6692
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 78%]:
# Trainning loss 0.0110265250 Acc.: 0.7808
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 89%]:
# Trainning loss 0.0121207597 Acc.: 0.8923
# ----#------#-----#-----#-----#-----#-----#-----
# [Tensor_CSPNet: Sub No.9/9 Fold 10/10, Epoch 50/50, Completed 100%]:
# Trainning loss 0.0147319190 Acc.: 1.0000
# ###############################################################
# START TESTING
# ###############################################################
# -----------------------------------
# Testing Batch 0:
#   Pred Label: [1 2 0 0 1 0 2 3 1 3 3 2 2 1 3 1 1 3 3 3 0 0 1 0 3 2 0 0]
# Ground Truth: [1 2 0 0 1 0 1 3 1 3 3 2 2 1 3 2 1 3 3 1 0 0 2 2 3 2 0 0]
# ##################################################################
# Tensor_CSPNet Testing Loss.: 0.020234 Acc: 0.821429
